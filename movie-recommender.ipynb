# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
print("Libraries ready!")
# Out:
# Libraries ready!

# %%
movies = pd.DataFrame({
    'title': ['The Dark Knight', 'Inception', 'Interstellar', 
              'The Avengers', 'Iron Man', 'Spider-Man',
              'The Godfather', 'Pulp Fiction', 'Fight Club',
              'Toy Story', 'Finding Nemo', 'The Lion King'],
    'genres': ['action crime drama', 'action sci-fi thriller', 'sci-fi drama adventure',
               'action sci-fi superhero', 'action sci-fi superhero', 'action superhero adventure',
               'crime drama thriller', 'crime drama thriller', 'drama thriller',
               'animation comedy adventure', 'animation comedy adventure', 'animation drama adventure']
})

print(movies)
# Out:
#               title                      genres
# 0   The Dark Knight          action crime drama
# 1         Inception      action sci-fi thriller
# 2      Interstellar      sci-fi drama adventure
# 3      The Avengers     action sci-fi superhero
# 4          Iron Man     action sci-fi superhero
# 5        Spider-Man  action superhero adventure
# 6     The Godfather        crime drama thriller
# 7      Pulp Fiction        crime drama thriller
# 8        Fight Club              drama thriller
# 9         Toy Story  animation comedy adventure
# 10     Finding Nemo  animation comedy adventure
# 11    The Lion King   animation drama adventure

# %%
# Step 1: Convert genres (text) into numbers using TF-IDF
tfidf = TfidfVectorizer()
tfidf_matrix = tfidf.fit_transform(movies['genres'])

# Step 2: Calculate similarity score between all movies
similarity = cosine_similarity(tfidf_matrix)

# Step 3: Build the recommendation function
def recommend(movie_name):
    # Find the index of the given movie
    idx = movies[movies['title'] == movie_name].index[0]
    
    # Get similarity scores of this movie with all others
    scores = list(enumerate(similarity[idx]))
    
    # Sort movies by similarity score (highest first)
    scores = sorted(scores, key=lambda x: x[1], reverse=True)
    
    # Pick top 3 (skip index 0 as it's the movie itself)
    scores = scores[1:4]
    
    print(f"\nIf you liked '{movie_name}', you might also enjoy:\n")
    for i, score in scores:
        print(f"  🎬 {movies['title'][i]}")

# Test the recommender with a movie
recommend('The Dark Knight')
# Out:
# If you liked 'The Dark Knight', you might also enjoy:
#
#   🎬 The Godfather
#   🎬 Pulp Fiction
#   🎬 Fight Club

# %%
recommend('Toy Story')
# Out:
# If you liked 'Toy Story', you might also enjoy:
#
#   🎬 Finding Nemo
#   🎬 The Lion King
#   🎬 Spider-Man
